# %% [markdown]
# <a href="https://colab.research.google.com/github/aarong31/Parkinsons-PredictiveModel-Using-Spiral-Drawings/blob/master/ParkinsonsSpiralDrawingsModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
import PIL
import numpy as np
import os
from matplotlib.pyplot import imshow
from PIL import Image
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator

from google.colab import drive
drive.mount('/content/gdrive')
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'Save_Model16.h5'
img_width, img_height = 128,128

datagen = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.05,
        height_shift_range=0.05,
        rescale=1/255,
        shear_range=0.1,
        zoom_range=0.1,
        horizontal_flip=True,
        fill_mode='nearest')


train_data_dir = 'data/train'
validation_data_dir = 'data/validation'
nb_train_samples = 2000
nb_validation_samples = 800
epochs = 50
batch_size = 16

if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)


model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(150, 150, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Flatten()) 
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))


model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

batch_size = 16


train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)


test_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
        '/content/gdrive/My Drive/detect-parkinsons/dataset/spiral/training',  
        target_size=(150, 150),  
        batch_size=batch_size,
        class_mode='binary')  

validation_generator = test_datagen.flow_from_directory(
        '/content/gdrive/My Drive/detect-parkinsons/dataset/spiral/testing',
        target_size=(150, 150),
        batch_size=batch_size,
        class_mode='binary')
model.fit_generator(
        train_generator,
        steps_per_epoch=2000 // batch_size,
        epochs=50,
        shuffle = True,
        validation_data=validation_generator,
        validation_steps=800 // batch_size)
model.save_weights('Saved_Model6.h5')


if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('Saved trained model at %s ' % model_path)
# Out:
# Mounted at /content/gdrive
# Found 1584 images belonging to 2 classes.
# Found 660 images belonging to 2 classes.
# Epoch 1/50
# 125/125 [==============================] - 23s 186ms/step - loss: 0.7097 - acc: 0.4815 - val_loss: 0.6960 - val_acc: 0.4873
# Epoch 2/50
# 125/125 [==============================] - 21s 170ms/step - loss: 0.7031 - acc: 0.4900 - val_loss: 0.6934 - val_acc: 0.4391
# Epoch 3/50
# 125/125 [==============================] - 21s 170ms/step - loss: 0.7007 - acc: 0.5230 - val_loss: 0.6550 - val_acc: 0.7119
# Epoch 4/50
# 125/125 [==============================] - 21s 169ms/step - loss: 0.6715 - acc: 0.6260 - val_loss: 0.6639 - val_acc: 0.6371
# Epoch 5/50
# 125/125 [==============================] - 21s 168ms/step - loss: 0.6353 - acc: 0.6665 - val_loss: 0.8465 - val_acc: 0.5609
# Epoch 6/50
# 125/125 [==============================] - 22s 172ms/step - loss: 0.5903 - acc: 0.7000 - val_loss: 0.7560 - val_acc: 0.7358
# Epoch 7/50
# ...
